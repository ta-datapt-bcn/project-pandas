# %%
import json
import requests
import pandas as pd

# %%
#API calls

response = requests.get('https://jsonplaceholder.typicode.com/todos')

# %%
#quiero obtener los resultados en un formato de json

results = response.json()

#esto va a crear un set de datos

results
# Out:
# [{'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False},
#  {'userId': 1,
#   'id': 2,
#   'title': 'quis ut nam facilis et officia qui',
#   'completed': False},
#  {'userId': 1, 'id': 3, 'title': 'fugiat veniam minus', 'completed': False},
#  {'userId': 1, 'id': 4, 'title': 'et porro tempora', 'completed': True},
#  {'userId': 1,
#   'id': 5,
#   'title': 'laboriosam mollitia et enim quasi adipisci quia provident illum',
#   'completed': False},
#  {'userId': 1,
#   'id': 6,
#   'title': 'qui ullam ratione quibusdam voluptatem quia omnis',
#   'completed': False},
#  {'userId': 1,
#   'id': 7,
#   'title': 'illo expedita consequatur quia in',
#   'completed': False},
#  {'userId': 1,
#   'id': 8,
#   'title': 'quo adipisci enim quam ut ab',
#   'completed': True},
#  {'userId': 1,
#   'id': 9,
#   'title': 'molestiae perspiciatis ipsa',
#   'completed': False},
#  {'userId': 1,
#   'id': 10,
#   'title': 'illo est ratione doloremque quia maiores aut',
# ...

# %%
#ponemos esto a un dataframe

data = pd.DataFrame(results)
data.head()
# Out:
#    completed  id                                              title  userId
# 0      False   1                                 delectus aut autem       1
# 1      False   2                 quis ut nam facilis et officia qui       1
# 2      False   3                                fugiat veniam minus       1
# 3       True   4                                   et porro tempora       1
# 4      False   5  laboriosam mollitia et enim quasi adipisci qui...       1

# %%
resp = requests.get('https://api.github.com/events')

data = pd.DataFrame(resp.json())

data.head()

#los datos no se pueden leer porque están nested
# Out:
#                                                actor            created_at  \
# 0  {'id': 9075125, 'login': 'Trisk3lion', 'displa...  2019-07-04T19:18:51Z
# 1  {'id': 6667815, 'login': 'Stallix', 'display_l...  2019-07-04T19:18:51Z
# 2  {'id': 1222034, 'login': 'justinlubin', 'displ...  2019-07-04T19:18:51Z
# 3  {'id': 37617801, 'login': 'airielo', 'display_...  2019-07-04T19:18:51Z
# 4  {'id': 45768228, 'login': 'DRyanMiller', 'disp...  2019-07-04T19:18:51Z
#
#            id                                                org  \
# 0  9952005191                                                NaN
# 1  9952005189  {'id': 50197624, 'login': 'Evolution-X', 'grav...
# 2  9952005188                                                NaN
# 3  9952005180                                                NaN
# 4  9952005177                                                NaN
#
#                                              payload  public  \
# ...

# %%
from pandas.io.json import json_normalize

# %%
#con esto crea un json con los resultados
results = resp.json()

flattened_data = json_normalize(results)

flattened_data.head()
# Out:
#                                     actor.avatar_url actor.display_login  \
# 0   https://avatars.githubusercontent.com/u/9075125?          Trisk3lion
# 1   https://avatars.githubusercontent.com/u/6667815?             Stallix
# 2   https://avatars.githubusercontent.com/u/1222034?         justinlubin
# 3  https://avatars.githubusercontent.com/u/37617801?             airielo
# 4  https://avatars.githubusercontent.com/u/45768228?         DRyanMiller
#
#   actor.gravatar_id  actor.id  actor.login  \
# 0                     9075125   Trisk3lion
# 1                     6667815      Stallix
# 2                     1222034  justinlubin
# 3                    37617801      airielo
# 4                    45768228  DRyanMiller
#
#                                   actor.url            created_at          id  \
# 0   https://api.github.com/users/Trisk3lion  2019-07-04T19:18:51Z  9952005191
# 1      https://api.github.com/users/Stallix  2019-07-04T19:18:51Z  9952005189
# ...

# %%
#cuando ponemos una exclamación delante de algo, es para usar el notebook como si fuera el terminal

#añadiendo > index.html guarda la info en un archivo html

# !curl www.ironhack.com > index.html
# Out:
# <!DOCTYPE html><html><head><title>Ironhack Web Development Bootcamp & UX/UI Design Bootcamp</title><meta name="description" content="Learn to code and UX/UI design through one of our full time or part time courses. Web Development Bootcamp and UX/UI Design Bootcamp in Madrid, Barcelona, Miami, Paris, Mexico City, Berlin, Bogotá, Lisbon and Munich."><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no,minimal-ui"><meta name="msapplication-TileColor" content="#673ab8"><meta name="msapplication-TileImage" content="./assets/icons/mstile-150x150.png"><meta name="apple-mobile-web-app-capable" content="yes"><meta name="apple-mobile-web-app-status-bar-style" content="black-translucent"><meta name="apple-mobile-web-app-title" content="Ironhack School"><meta name="application-name" content="Ironhack School"><meta name="format-detection" content="telephone=no"><meta name="theme-color" content="#673ab8"><link rel="stylesheet" hr
# ...
